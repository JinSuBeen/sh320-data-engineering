# %% [markdown]
# ## <strong> 13. 시계열 전용 연산

# %% [markdown]
# 필요한 라이브러리: ```yfinance```, ```pandas_datareader```

# %%
# !pip install yfinance
# Out:
# Collecting yfinance
#   Obtaining dependency information for yfinance from https://files.pythonhosted.org/packages/57/e5/c0a26615f1d0b7da047af9b5e60ca899181a123e5199277025ad4567e361/yfinance-0.2.60-py2.py3-none-any.whl.metadata
#   Downloading yfinance-0.2.60-py2.py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\khl38\appdata\local\programs\python\python311\lib\site-packages (from yfinance) (2.2.3)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\khl38\appdata\local\programs\python\python311\lib\site-packages (from yfinance) (1.26.4)
# Requirement already satisfied: requests>=2.31 in c:\users\khl38\appdata\local\programs\python\python311\lib\site-packages (from yfinance) (2.32.3)
# Collecting multitasking>=0.0.7 (from yfinance)
#   Obtaining dependency information for multitasking>=0.0.7 from https://files.pythonhosted.org/packages/3e/8a/bb3160e76e844db9e69a413f055818969c8acade64e1a9ac5ce9dfdcf6c1/multitasking-0.0.11-py3-none-any.whl.metadata
#   Downloading multitasking-0.0.11-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: platformdirs>=2.0.0 in c:\users\khl38\appdata\roaming\python\python311\site-packages (from yfinance) (4.3.6)
# Requirement already satisfied: pytz>=2022.5 in c:\users\khl38\appdata\local\programs\python\python311\lib\site-packages (from yfinance) (2025.2)
# Collecting frozendict>=2.3.4 (from yfinance)
#   Obtaining dependency information for frozendict>=2.3.4 from https://files.pythonhosted.org/packages/04/13/d9839089b900fa7b479cce495d62110cddc4bd5630a04d8469916c0e79c5/frozendict-2.4.6-py311-none-any.whl.metadata
#   Downloading frozendict-2.4.6-py311-none-any.whl.metadata (23 kB)
# Collecting peewee>=3.16.2 (from yfinance)
#   Downloading peewee-3.18.1.tar.gz (3.0 MB)
#      ---------------------------------------- 0.0/3.0 MB ? eta -:--:--
#       --------------------------------------- 0.1/3.0 MB 1.7 MB/s eta 0:00:02
#      ---- ----------------------------------- 0.3/3.0 MB 4.8 MB/s eta 0:00:01
#      -------- ------------------------------- 0.6/3.0 MB 4.8 MB/s eta 0:00:01
#      --------- ------------------------------ 0.7/3.0 MB 4.2 MB/s eta 0:00:01
#      ----------- ---------------------------- 0.9/3.0 MB 4.2 MB/s eta 0:00:01
#      -------------- ------------------------- 1.1/3.0 MB 4.3 MB/s eta 0:00:01
#      ----------------- ---------------------- 1.3/3.0 MB 4.1 MB/s eta 0:00:01
#      ------------------- -------------------- 1.5/3.0 MB 4.1 MB/s eta 0:00:01
#      --------------------- ------------------ 1.7/3.0 MB 4.2 MB/s eta 0:00:01
#      ------------------------- -------------- 1.9/3.0 MB 4.2 MB/s eta 0:00:01
#      ---------------------------- ----------- 2.2/3.0 MB 4.3 MB/s eta 0:00:01
#      -------------------------------- ------- 2.4/3.0 MB 4.4 MB/s eta 0:00:01
#      ---------------------------------- ----- 2.6/3.0 MB 4.6 MB/s eta 0:00:01
#      -------------------------------------- - 2.9/3.0 MB 4.5 MB/s eta 0:00:01
#      ---------------------------------------- 3.0/3.0 MB 4.4 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\khl38\appdata\local\programs\python\python311\lib\site-packages (from yfinance) (4.13.4)
# Collecting curl_cffi>=0.7 (from yfinance)
#   Obtaining dependency information for curl_cffi>=0.7 from https://files.pythonhosted.org/packages/26/80/dbc3a5119afe233ddc9dfc14d5b175636443e5d6349f4cdce3eaa9e1523a/curl_cffi-0.10.0-cp39-abi3-win_amd64.whl.metadata
#   Downloading curl_cffi-0.10.0-cp39-abi3-win_amd64.whl.metadata (12 kB)
# Collecting protobuf>=3.19.0 (from yfinance)
#   Obtaining dependency information for protobuf>=3.19.0 from https://files.pythonhosted.org/packages/97/e9/7b9f1b259d509aef2b833c29a1f3c39185e2bf21c9c1be1cd11c22cb2149/protobuf-6.30.2-cp310-abi3-win_amd64.whl.metadata
#   Downloading protobuf-6.30.2-cp310-abi3-win_amd64.whl.metadata (593 bytes)
# Collecting websockets>=13.0 (from yfinance)
#   Obtaining dependency information for websockets>=13.0 from https://files.pythonhosted.org/packages/98/93/e36c73f78400a65f5e236cd376713c34182e6663f6889cd45a4a04d8f203/websockets-15.0.1-cp311-cp311-win_amd64.whl.metadata
#   Downloading websockets-15.0.1-cp311-cp311-win_amd64.whl.metadata (7.0 kB)
# Requirement already satisfied: soupsieve>1.2 in c:\users\khl38\appdata\local\programs\python\python311\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.6)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\khl38\appdata\roaming\python\python311\site-packages (from beautifulsoup4>=4.11.1->yfinance) (4.12.2)
# Collecting cffi>=1.12.0 (from curl_cffi>=0.7->yfinance)
#   Obtaining dependency information for cffi>=1.12.0 from https://files.pythonhosted.org/packages/3d/97/50228be003bb2802627d28ec0627837ac0bf35c90cf769812056f235b2d1/cffi-1.17.1-cp311-cp311-win_amd64.whl.metadata
#   Downloading cffi-1.17.1-cp311-cp311-win_amd64.whl.metadata (1.6 kB)
# Requirement already satisfied: certifi>=2024.2.2 in c:\users\khl38\appdata\local\programs\python\python311\lib\site-packages (from curl_cffi>=0.7->yfinance) (2025.1.31)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\khl38\appdata\local\programs\python\python311\lib\site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\khl38\appdata\local\programs\python\python311\lib\site-packages (from pandas>=1.3.0->yfinance) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\khl38\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.31->yfinance) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\khl38\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.31->yfinance) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\khl38\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.31->yfinance) (2.4.0)
# Collecting pycparser (from cffi>=1.12.0->curl_cffi>=0.7->yfinance)
#   Obtaining dependency information for pycparser from https://files.pythonhosted.org/packages/13/a3/a812df4e2dd5696d1f351d58b8fe16a405b234ad2886a0dab9183fb78109/pycparser-2.22-py3-none-any.whl.metadata
#   Downloading pycparser-2.22-py3-none-any.whl.metadata (943 bytes)
# Requirement already satisfied: six>=1.5 in c:\users\khl38\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.16.0)
# Downloading yfinance-0.2.60-py2.py3-none-any.whl (117 kB)
#    ---------------------------------------- 0.0/117.9 kB ? eta -:--:--
#    ---------------------------------------- 117.9/117.9 kB 7.2 MB/s eta 0:00:00
# Downloading curl_cffi-0.10.0-cp39-abi3-win_amd64.whl (1.4 MB)
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    -------- ------------------------------- 0.3/1.4 MB 5.7 MB/s eta 0:00:01
#    --------------- ------------------------ 0.5/1.4 MB 5.6 MB/s eta 0:00:01
#    ---------------------- ----------------- 0.8/1.4 MB 5.3 MB/s eta 0:00:01
#    ----------------------------- ---------- 1.0/1.4 MB 5.3 MB/s eta 0:00:01
#    ------------------------------------- -- 1.3/1.4 MB 5.4 MB/s eta 0:00:01
#    ---------------------------------------- 1.4/1.4 MB 5.1 MB/s eta 0:00:00
# Downloading frozendict-2.4.6-py311-none-any.whl (16 kB)
# Downloading multitasking-0.0.11-py3-none-any.whl (8.5 kB)
# Downloading protobuf-6.30.2-cp310-abi3-win_amd64.whl (431 kB)
#    ---------------------------------------- 0.0/431.0 kB ? eta -:--:--
#    ---------------------- ----------------- 245.8/431.0 kB 7.6 MB/s eta 0:00:01
#    ------------------------------------- -- 399.4/431.0 kB 5.0 MB/s eta 0:00:01
#    ---------------------------------------- 431.0/431.0 kB 4.5 MB/s eta 0:00:00
# Downloading websockets-15.0.1-cp311-cp311-win_amd64.whl (176 kB)
#    ---------------------------------------- 0.0/176.8 kB ? eta -:--:--
#    ---------------------------------------  174.1/176.8 kB 5.3 MB/s eta 0:00:01
#    ---------------------------------------- 176.8/176.8 kB 3.5 MB/s eta 0:00:00
# Downloading cffi-1.17.1-cp311-cp311-win_amd64.whl (181 kB)
#    ---------------------------------------- 0.0/181.4 kB ? eta -:--:--
#    -------------------------------------- - 174.1/181.4 kB 5.3 MB/s eta 0:00:01
#    ---------------------------------------- 181.4/181.4 kB 3.6 MB/s eta 0:00:00
# Downloading pycparser-2.22-py3-none-any.whl (117 kB)
#    ---------------------------------------- 0.0/117.6 kB ? eta -:--:--
#    ---------------------------------------- 117.6/117.6 kB 7.2 MB/s eta 0:00:00
# Building wheels for collected packages: peewee
#   Building wheel for peewee (pyproject.toml): started
#   Building wheel for peewee (pyproject.toml): finished with status 'done'
#   Created wheel for peewee: filename=peewee-3.18.1-py3-none-any.whl size=139099 sha256=f0f815b2a5ab78b705d5085e567d84c641dc6a7101a2ea59efba7ee28c8149aa
#   Stored in directory: c:\users\khl38\appdata\local\pip\cache\wheels\25\cb\79\a133a0d1d75f318a96614ed7fb97bdf2f35a7b6c4d4e426e3f
# Successfully built peewee
# Installing collected packages: peewee, multitasking, websockets, pycparser, protobuf, frozendict, cffi, curl_cffi, yfinance
# Successfully installed cffi-1.17.1 curl_cffi-0.10.0 frozendict-2.4.6 multitasking-0.0.11 peewee-3.18.1 protobuf-6.30.2 pycparser-2.22 websockets-15.0.1 yfinance-0.2.60
# [notice] A new release of pip is available: 23.2.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import yfinance as yf
import pandas as pd
from matplotlib import pyplot as plt

# %%
# 구글 주식 데이터 로딩
goog = yf.download("GOOG", start="2004-01-01", end="2024-12-31")
goog.head()
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed
# Price          Close      High       Low      Open     Volume
# Ticker          GOOG      GOOG      GOOG      GOOG       GOOG
# Date
# 2004-08-19  2.487352  2.579567  2.378775  2.478922  897427216
# 2004-08-20  2.684922  2.704009  2.491318  2.503960  458857488
# 2004-08-23  2.711942  2.813082  2.703266  2.745408  366857939
# 2004-08-24  2.599647  2.766478  2.567421  2.757554  306396159
# 2004-08-25  2.627658  2.677237  2.575105  2.601877  184645512

# %%
# [+] 종가(Close) 데이터만 사용하기
goog = goog['Close']
goog
# Out:
# Ticker            GOOG
# Date
# 2004-08-19    2.487352
# 2004-08-20    2.684922
# 2004-08-23    2.711942
# 2004-08-24    2.599647
# 2004-08-25    2.627658
# ...                ...
# 2024-12-23  195.766968
# 2024-12-24  197.345184
# 2024-12-26  196.875717
# 2024-12-27  193.819183
# 2024-12-30  192.470734
#
# [5126 rows x 1 columns]

# %%
# [+] Lineplot 시각화
goog.plot()
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# #### <strong> 리샘플링(Resampling)
# + ```resample()```: 빈도를 기준으로 집계 연산
# + ```asfreq()```: 빈도 단위 별 데이터 선택

# %%
# [+] 다운샘플링: resample()
goog_downsampled = goog.resample('ME').mean()
goog_downsampled
# Out:
# Ticker            GOOG
# Date
# 2004-08-31    2.609370
# 2004-09-30    2.806814
# 2004-10-31    3.798477
# 2004-11-30    4.399970
# 2004-12-31    4.505938
# ...                ...
# 2024-08-31  164.728805
# 2024-09-30  158.933694
# 2024-10-31  166.526794
# 2024-11-30  174.757920
# 2024-12-31  187.922451
#
# [245 rows x 1 columns]

# %%
fig, ax = plt.subplots(2, 1, sharey=True, figsize=(12, 6))
goog.plot(label='original', ax=ax[0])
ax[0].legend()
goog_downsampled.plot(label='downsampled', ax=ax[1])
ax[1].legend()
plt.tight_layout()

# %%
# [+] 다운샘플링: asfreq()
goog_downsampled = goog.asfreq('ME').plot()
print(goog_downsampled)

goog_downsampled.plot()
# Out:
# Axes(0.125,0.11;0.775x0.77)
# []

# %%
# [+] 업샘플링: resample()
goog_upsampled = goog.resample('12h').mean()
print(goog_upsampled)
# Out:
# Ticker                     GOOG
# Date
# 2004-08-19 00:00:00    2.487352
# 2004-08-19 12:00:00         NaN
# 2004-08-20 00:00:00    2.684922
# 2004-08-20 12:00:00         NaN
# 2004-08-21 00:00:00         NaN
# ...                         ...
# 2024-12-28 00:00:00         NaN
# 2024-12-28 12:00:00         NaN
# 2024-12-29 00:00:00         NaN
# 2024-12-29 12:00:00         NaN
# 2024-12-30 00:00:00  192.470734
#
# [14877 rows x 1 columns]

# %% [markdown]
# #### <strong> 시프팅(Shifting)
# + ```shift(periods)``` : ```periods``` 값 만큼 시계열 이동

# %%
# [+] 900일 뒤로 시프팅 적용
goog_shifted = goog.shift(periods=900)
goog_shifted
# Out:
# Ticker            GOOG
# Date
# 2004-08-19         NaN
# 2004-08-20         NaN
# 2004-08-23         NaN
# 2004-08-24         NaN
# 2004-08-25         NaN
# ...                ...
# 2024-12-23  121.102898
# 2024-12-24  119.559212
# 2024-12-26  120.009583
# 2024-12-27  120.917778
# 2024-12-30  120.493286
#
# [5126 rows x 1 columns]

# %%
fig, ax = plt.subplots(2, 1, sharey=True, figsize=(12, 6))

# Legends and annotations
local_max = pd.to_datetime('2007-11-05')
offset = pd.Timedelta(900, 'D')

goog.plot(label='original', ax=ax[0])
ax[0].legend()
ax[0].get_xticklabels()[2].set(weight='heavy', color='red')
ax[0].axvline(local_max, alpha=0.3, color='red')

goog_shifted.plot(label='shifted 900 days', ax=ax[1])
ax[1].legend()
ax[1].get_xticklabels()[2].set(weight='heavy', color='red')
ax[1].axvline(local_max + offset, alpha=0.3, color='red')

plt.tight_layout()

# %%
# shifting 응용: 주가 변화율 계산
goog_shifted = goog.shift(periods=1) # [+] 시프팅
(goog - goog_shifted) / goog_shifted # [+] 주가 변화율 계산
# Out:
# Ticker          GOOG
# Date
# 2004-08-19       NaN
# 2004-08-20  0.079430
# 2004-08-23  0.010064
# 2004-08-24 -0.041408
# 2004-08-25  0.010775
# ...              ...
# 2024-12-23  0.015703
# 2024-12-24  0.008062
# 2024-12-26 -0.002379
# 2024-12-27 -0.015525
# 2024-12-30 -0.006957
#
# [5126 rows x 1 columns]

# %%
# shifting 응용: 차분 시계열 구하기
goog_diff = goog - goog_shifted  # [+] 차분
print(goog_diff)

goog_diff.plot()
# Out:
# Ticker          GOOG
# Date
# 2004-08-19       NaN
# 2004-08-20  0.197570
# 2004-08-23  0.027020
# 2004-08-24 -0.112295
# 2004-08-25  0.028011
# ...              ...
# 2024-12-23  3.026550
# 2024-12-24  1.578217
# 2024-12-26 -0.469467
# 2024-12-27 -3.056534
# 2024-12-30 -1.348450
#
# [5126 rows x 1 columns]
# <Axes: xlabel='Date'>

# %% [markdown]
# #### <strong> 윈도잉(Windowing)

# %%
# [+] 365일 단위 윈도잉
goog_rolled = goog.rolling(365)
print(goog_rolled)

goog_rolled.mean().plot()
# Out:
# Rolling [window=365,center=False,axis=0,method=single]
# <Axes: xlabel='Date'>

# %%
data = pd.DataFrame({'input': goog.values.flatten(),
                     # moving average
                     'one-year rolling_mean': goog_rolled.mean().values.flatten(), 
                     # standard deviation
                     'one-year rolling_std': goog_rolled.std().values.flatten()}, index=goog.index)
ax = data.plot(style=['-', '--', ':'])
ax.lines[0].set_alpha(0.3)
